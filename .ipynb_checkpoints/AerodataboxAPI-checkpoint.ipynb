# %%
import datetime
from IPython.display import JSON
import pandas as pd

# %%
today = datetime.date.today()
tomorrow = str(today + datetime.timedelta(days=1))

# %%
import requests

url = f"https://aerodatabox.p.rapidapi.com/flights/airports/icao/EDDB/{tomorrow}T00:00/{tomorrow}T11:59"

querystring = {"withLeg":"true","direction":"Arrival","withCancelled":"false","withCodeshared":"true","withCargo":"false","withPrivate":"false","withLocation":"false"}

headers = {
    'x-rapidapi-host': "aerodatabox.p.rapidapi.com",
    'x-rapidapi-key': "5816e969d8mshd4f781dd3077706p10311ajsn43dd0b10811c"
    }

response = requests.request("GET", url, headers=headers, params=querystring)

# %%
url = f"https://aerodatabox.p.rapidapi.com/flights/airports/icao/EDDB/{tomorrow}T12:00/{tomorrow}T23:59"

querystring = {"withLeg":"true","direction":"Arrival","withCancelled":"false","withCodeshared":"true","withCargo":"false","withPrivate":"false","withLocation":"false"}

headers = {
    'x-rapidapi-host': "aerodatabox.p.rapidapi.com",
    'x-rapidapi-key': "5816e969d8mshd4f781dd3077706p10311ajsn43dd0b10811c"
    }

response2 = requests.request("GET", url, headers=headers, params=querystring)

# %%
flights_json = response.json()
flights2_json = response2.json()
jsons= [flights_json,flights2_json]

# %%
# flights_json['arrivals'][0]['arrival']["scheduledTimeLocal"][:-6]

# %%
dictionary = {"From":[],"Arrival (Local time)":[], "Arrival (UTC time)":[],"Terminal":[],"Airline":[],"Flight number":[],"Aircraft model":[]}
for j in jsons:
    for flight in j['arrivals']:
        try:
            dictionary["From"].append(flight['departure']["airport"]['name'])
        except:
            dictionary["From"].append("Unknown")
        try:
            dictionary["Arrival (Local time)"].append(flight['arrival']["scheduledTimeLocal"][:-6])
        except:
            dictionary["Arrival (Local time)"].append("Unknown")
        try:
            dictionary["Arrival (UTC time)"].append(flight['arrival']["scheduledTimeUtc"][:-1])
        except:
            dictionary["Arrival (UTC time)"].append("Unknown")
        try:
            dictionary["Terminal"].append(flight['arrival']["terminal"])
        except:
            dictionary["Terminal"].append("Unknown")
        try:
            dictionary["Airline"].append(flight['airline']["name"])
        except:
            dictionary["Airline"].append("Unknown")
        try:
            dictionary["Flight number"].append(flight['number'])
        except:
            dictionary["Flight number"].append("Unknown")
        try:
            dictionary["Aircraft model"].append(flight['aircraft']["model"])
        except:
            dictionary["Aircraft model"].append("Unknown")

# %%
flights = pd.DataFrame.from_dict(dictionary)

# %%
flights
# Out:
#                   From Arrival (Local time) Arrival (UTC time) Terminal  \
# 0             Brussels     2021-11-25 11:15   2021-11-25 10:15        1
# 1    Frankfurt-am-Main     2021-11-25 07:55   2021-11-25 06:55        1
# 2    Frankfurt-am-Main     2021-11-25 08:55   2021-11-25 07:55        1
# 3    Frankfurt-am-Main     2021-11-25 09:55   2021-11-25 08:55        1
# 4    Frankfurt-am-Main     2021-11-25 11:55   2021-11-25 10:55        1
# ..                 ...                  ...                ...      ...
# 175              Milan     2021-11-25 22:30   2021-11-25 21:30        1
# 176      Bâle/Mulhouse     2021-11-25 22:20   2021-11-25 21:20        1
# 177         Copenhagen     2021-11-25 22:30   2021-11-25 21:30        1
# 178  Palma De Mallorca     2021-11-25 22:30   2021-11-25 21:30        1
# 179    Tenerife Island     2021-11-25 22:25   2021-11-25 21:25        1
#
#        Airline Flight number Aircraft model
# 0     Brussels       SN 2581    Airbus A319
# 1    Lufthansa        LH 170    Airbus A321
# 2    Lufthansa        LH 174    Airbus A320
# 3    Lufthansa        LH 176    Airbus A320
# 4    Lufthansa        LH 180    Airbus A320
# ..         ...           ...            ...
# 175    easyJet       U2 4678    Airbus A320
# 176    easyJet       U2 5640    Airbus A320
# 177    easyJet       U2 5690    Airbus A320
# 178    easyJet       U2 5808    Airbus A320
# 179    easyJet       U2 5916    Airbus A320
#
# [180 rows x 7 columns]
